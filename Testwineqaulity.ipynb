# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
data = pd.read_csv('winequality.csv', sep=';')

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# to print a list of all the variable names we have in the dataset
data.keys()
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
## to get all the unique values in the PH column
len(np.unique(data['pH']))
# Out:
# 89

# %%
#this cell shows the total number of unique values in all the columns in the dataset.
for i in data.keys():
    print(f"Column {i} has {len(np.unique(data[i]))} Uniques values")
# Out:
# Column fixed acidity has 96 Uniques values
# Column volatile acidity has 143 Uniques values
# Column citric acid has 80 Uniques values
# Column residual sugar has 91 Uniques values
# Column chlorides has 153 Uniques values
# Column free sulfur dioxide has 60 Uniques values
# Column total sulfur dioxide has 144 Uniques values
# Column density has 436 Uniques values
# Column pH has 89 Uniques values
# Column sulphates has 96 Uniques values
# Column alcohol has 65 Uniques values
# Column quality has 6 Uniques values

# %%
fig,ax = plt.subplots(1, figsize=(18,5))

sns.boxplot(data=data)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
plt.show()

# %%
data = data[data['total sulfur dioxide'] < 200]

# %%
data
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
# visual data exp
#loration

sns.scatterplot(x=data['residual sugar'], y=data['alcohol'])
# Out:
# <AxesSubplot:xlabel='residual sugar', ylabel='alcohol'>

# %%
data.keys()
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
sns.scatterplot(x=data['density'], y=data['alcohol'])
# Out:
# <AxesSubplot:xlabel='density', ylabel='alcohol'>

# %%
data['quality']
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1594    5
# 1595    6
# 1596    6
# 1597    5
# 1598    6
# Name: quality, Length: 1597, dtype: int64

# %%
## to check if any of the variables are changing with respect to the data qaulity
cols2plot = ['fixed acidity','citric acid', 'alcohol', 'pH', 'quality']
sns.pairplot(data[cols2plot], kind='reg', hue='quality')
plt.show()
